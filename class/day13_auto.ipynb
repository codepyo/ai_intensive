# %%
import pandas as pd
from pycaret.classification import *

df = pd.read_csv('../data/wine_data.csv')

exp1 = setup(data=df, target='class', session_id=123)
# Out:
# <style type="text/css">
# #T_cd80b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cd80b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd80b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cd80b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd80b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd80b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cd80b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_cd80b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd80b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cd80b_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_cd80b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_5546a th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_8b147_row10_col0, #T_8b147_row10_col1, #T_8b147_row10_col2, #T_8b147_row10_col3, #T_8b147_row10_col4, #T_8b147_row10_col5, #T_8b147_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8b147">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b147_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8b147_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8b147_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8b147_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8b147_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8b147_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8b147_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e68fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e68fd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e68fd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e68fd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e68fd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e68fd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e68fd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e68fd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e68fd_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e68fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e68fd_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
# ...

# %%
final_model = finalize_model(tuned_model)

# %%
save_model(final_model, 'wine_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Alcohol', 'Malic', 'Ash',
#                                               'Alcalinity', 'Magesium',
#                                               'Phenols', 'Flavanoids',
#                                               'Nonflavanoids', 'Proanthocyanins',
#                                               'Color', 'Hue', 'Dilution',
#                                               'Proline'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
# ...

# %%
loaded_model = load_model('wine_model')
new_data = df.iloc[20:40, 0:-1]
predictions = predict_model(loaded_model, data=new_data)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predictions
# Out:
#     Alcohol  Malic   Ash  Alcalinity  Magesium  Phenols  Flavanoids  \
# 20    14.06   1.63  2.28   16.000000       126     3.00        3.17
# 21    12.93   3.80  2.65   18.600000       102     2.41        2.41
# 22    13.71   1.86  2.36   16.600000       101     2.61        2.88
# 23    12.85   1.60  2.52   17.799999        95     2.48        2.37
# 24    13.50   1.81  2.61   20.000000        96     2.53        2.61
# 25    13.05   2.05  3.22   25.000000       124     2.63        2.68
# 26    13.39   1.77  2.62   16.100000        93     2.85        2.94
# 27    13.30   1.72  2.14   17.000000        94     2.40        2.19
# 28    13.87   1.90  2.80   19.400000       107     2.95        2.97
# 29    14.02   1.68  2.21   16.000000        96     2.65        2.33
# 30    13.73   1.50  2.70   22.500000       101     3.00        3.25
# 31    13.58   1.66  2.36   19.100000       106     2.86        3.19
# 32    13.68   1.83  2.36   17.200001       104     2.42        2.69
# ...

# %%
from pycaret.regression import *
df = pd.read_csv('../data/house_prices.csv')

# %%
exp_reg = setup(data=df, target='MEDV', session_id=123)
# Out:
# <style type="text/css">
# #T_b84de_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b84de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b84de_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b84de_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b84de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b84de_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b84de_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b84de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b84de_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b84de_row1_col1" class="data row1 col1" >MEDV</td>
#     </tr>
#     <tr>
#       <th id="T_b84de_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_05537 th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_d7265_row10_col0, #T_d7265_row10_col1, #T_d7265_row10_col2, #T_d7265_row10_col3, #T_d7265_row10_col4, #T_d7265_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d7265">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7265_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d7265_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d7265_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d7265_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d7265_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d7265_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76556_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_76556_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_76556_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_76556_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_76556_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_76556_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_76556_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76556_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76556_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_76556_row0_col1" class="data row0 col1" >2.2456</td>
# ...

# %%
final_model = finalize_model(tuned_model)

# %%
save_model(final_model, 'house_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['CRIM', 'ZN', 'INDUS', 'CHAS',
#                                               'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#                                               'TAX', 'PTRATIO', 'B', 'LSTAT'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer'...
# ...

# %%
loaded_model = load_model('house_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_data = df.iloc[20:40, 0:-1]
predictions = predict_model(loaded_model, data=new_data)

# %%
predictions
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 20  1.25179   0.0   8.14     0  0.538  5.570   98.099998  3.7979    4  307
# 21  0.85204   0.0   8.14     0  0.538  5.965   89.199997  4.0123    4  307
# 22  1.23247   0.0   8.14     0  0.538  6.142   91.699997  3.9769    4  307
# 23  0.98843   0.0   8.14     0  0.538  5.813  100.000000  4.0952    4  307
# 24  0.75026   0.0   8.14     0  0.538  5.924   94.099998  4.3996    4  307
# 25  0.84054   0.0   8.14     0  0.538  5.599   85.699997  4.4546    4  307
# 26  0.67191   0.0   8.14     0  0.538  5.813   90.300003  4.6820    4  307
# 27  0.95577   0.0   8.14     0  0.538  6.047   88.800003  4.4534    4  307
# 28  0.77299   0.0   8.14     0  0.538  6.495   94.400002  4.4547    4  307
# 29  1.00245   0.0   8.14     0  0.538  6.674   87.300003  4.2390    4  307
# 30  1.13081   0.0   8.14     0  0.538  5.713   94.099998  4.2330    4  307
# ...
